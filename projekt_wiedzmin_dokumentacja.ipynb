# %% [markdown]
# <a href="https://colab.research.google.com/github/kzoord/repo-ujsieci/blob/nowa1/projekt_wiedzmin_dokumentacja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Treść zadania
#Napisanie funkcji, która poda tytuł odcinka serialu Wiedźmin (netflix)
#Wymagania:
#- Pisanie własnych funkcji
#- Numer odcinka wprowadza użytkownik z klawiatury (input)
#- Stworzenie dwóch wersji językowych, PL i ENG
#- Zabezpieczenie poprawności danych, w razie błędów mają się wyświetlać odpowiednie komunikaty
#- Możliwość powtórzenia procedury podania tytułu, możliwość zakończenia programu na życzenie użytkownika

#Zaczynam od stworzenia dwóch słowników: jeden w wersji polskiej (polskie tytuły) a drugi w angielskiej (angielskie tytuły)
wiedzminpl = {"1":"Początek końca", "2":"Cztery marki", "3":"Zdradziecki księżyc","4":"O bankietach, bękartach i pochówkach", "5":"Niespełnione pragnienia", "6":"Ginące gatunki","7":"Przed upadkiem","8":"Coś więcej"}
wiedzmineng = {"1":"The Ends Beginning", "2":"Four Marks","3":"Betrayer Moon", "4":"Of Banquates, Bastards and Burials", "5":"Bottled Appetites", "6":"Rare Spacies", "7":"Before a Fall", "8":"Much More"}

#Pierwsza funkcja odpowiada za wybór języka, użytkownik poprzez wpisanie odpowiedniego skrótu wybiera w jakim języku chce otrzymywać tytuły odcinków
def startwiedzmin():
  wybierzjezyk=input("Wybierz wersję językową: (PL/ENG)")#Wprowadzamy odpowiedni skrót
  if wybierzjezyk == "PL":
    print ("Będziesz dostawał polskie tytuły odcinków.")
    wiedzminpolska()#Po wpisaniu PL, uruchamiamy funkcję, która będzie nam wysyłać polskie tytuł odcinków
  elif wybierzjezyk == "ENG":
    print ("Będziesz dostawał angielskie tytuły odcinków.")
    wiedzminanglia()# Po wpisaniu ENG, uruchamiamy funkcję, któa będzie nam wysyłać angielskie tytuły odcinków
  else:
    print ("Wpisałeś zły skrót. Zaczynasz od początku")#Po wpisaniu innego ciągu znaków od PL lub ENG zobaczymy komunikat o błędzie
    startwiedzmin()



def wiedzminpolska():
  wpiszodc = int(input("Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) "))#Wpisujemy nr odcinka (1-8)
  if wpiszodc == 1:#Funkcja jest przygotowana osobno na wpisanie każdego odcinka
    print (wiedzminpl["1"])#Wyświetlanie konkretnego odcinka ze słownika
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")#Możliwość powtórzenia operacji
    if powtorka == "T":
      wiedzminpolska()#Po wpisaniu "T", włącza się od nowa funcja do wpisywania numerów odcinka
    elif powtorka == "N":#Po wpisaniu "N", funkcja pyta czy ma zakończyć działanie
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":#Po wpisaniu "T", dostajemy komunikat "Żegnaj"
        print ("Żegnaj.")
      elif zakonczenie == "N":#Po wpisaniu "N", funkcja uruchamia sie ponownie
        print ("Wracasz do początku")
        wiedzminpolska()
      else:#Po wpisaniu czegoś innego niż T lub N, dostajemy komunikat o błędzie
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:#Komunikat o błędzie, kiedy wpiszesz zły numer odcinka
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 2:#Reszta działa na takiej samej zasadzie jak wyżej
    print (wiedzminpl["2"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 3:
    print (wiedzminpl["3"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 4:
    print (wiedzminpl["4"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 5:
    print (wiedzminpl["5"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 6:
    print (wiedzminpl["6"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 7:
    print (wiedzminpl["7"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 8:
    print (wiedzminpl["8"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  else:
    print ("Wpisałeś zły numer odcinka, wracasz do początku.")
    wiedzminpolska()



def wiedzminanglia():#Funkcja pobierająca odcinki ze słownika z angielskimi odcinkami
  wpiszodceng = int(input("Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) "))
  if wpiszodceng == 1:#Reszta działa na takiej samej zasadzie jak w poprzedniej funkcji
    print (wiedzmineng["1"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 2:
    print (wiedzmineng["2"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 3:
    print (wiedzmineng["3"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 4:
    print (wiedzmineng["4"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 5:
    print (wiedzmineng["5"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 6:
    print (wiedzmineng["6"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 7:
    print (wiedzmineng["7"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 8:
    print (wiedzmineng["8"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzmineng()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  else:
    print ("Wpisałeś zły numer odcinka, wracasz do początku.")
    wiedzminanglia()
