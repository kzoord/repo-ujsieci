# %% [markdown]
# <a href="https://colab.research.google.com/github/kzoord/repo-ujsieci/blob/nowa1/projekt_wiedzmin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#zadanie wiedzmin

wiedzminpl = {"1":"Początek końca", "2":"Cztery marki", "3":"Zdradziecki księżyc","4":"O bankietach, bękartach i pochówkach", "5":"Niespełnione pragnienia", "6":"Ginące gatunki","7":"Przed upadkiem","8":"Coś więcej"}
wiedzmineng = {"1":"The Ends Beginning", "2":"Four Marks","3":"Betrayer Moon", "4":"Of Banquates, Bastards and Burials", "5":"Bottled Appetites", "6":"Rare Spacies", "7":"Before a Fall", "8":"Much More"}


def startwiedzmin():
  wybierzjezyk=input("Wybierz wersję językową: (PL/ENG)")
  if wybierzjezyk == "PL":
    print ("Będziesz dostawał polskie tytuły odcinków.")
    wiedzminpolska()
  elif wybierzjezyk == "ENG":
    print ("Będziesz dostawał angielskie tytuły odcinków.")
    wiedzminanglia()
  else:
    print ("Wpisałeś zły skrót. Zaczynasz od początku")
    startwiedzmin()



def wiedzminpolska():
  wpiszodc = int(input("Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) "))
  if wpiszodc == 1:
    print (wiedzminpl["1"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 2:
    print (wiedzminpl["2"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 3:
    print (wiedzminpl["3"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 4:
    print (wiedzminpl["4"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 5:
    print (wiedzminpl["5"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 6:
    print (wiedzminpl["6"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 7:
    print (wiedzminpl["7"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  elif wpiszodc == 8:
    print (wiedzminpl["8"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminpolska()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminpolska()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminpolska()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminpolska()
  else:
    print ("Wpisałeś zły numer odcinka, wracasz do początku.")
    wiedzminpolska()



def wiedzminanglia():
  wpiszodceng = int(input("Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) "))
  if wpiszodceng == 1:
    print (wiedzmineng["1"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 2:
    print (wiedzmineng["2"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 3:
    print (wiedzmineng["3"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 4:
    print (wiedzmineng["4"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 5:
    print (wiedzmineng["5"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 6:
    print (wiedzmineng["6"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 7:
    print (wiedzmineng["7"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzminanglia()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  elif wpiszodceng == 8:
    print (wiedzmineng["8"])
    powtorka = input("Czy chcesz powtórzyć operację? T/N ")
    if powtorka == "T":
      wiedzmineng()
    elif powtorka == "N":
      zakonczenie = input("Chcesz zakończyć działanie programu? T/N")
      if zakonczenie == "T":
        print ("Żegnaj.")
      elif zakonczenie == "N":
        print ("Wracasz do początku")
        wiedzminanglia()
      else:
        print("Wpisałeś coś źle, wracasz do początku")
        wiedzminanglia()
    else:
      print("Wpisales coś źle, wracasz do początku")
      wiedzminanglia()
  else:
    print ("Wpisałeś zły numer odcinka, wracasz do początku.")
    wiedzminanglia()

# %%
wiedzminpolska()
# Out:
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 3
# Zdradziecki księżyc
# Czy chcesz powtórzyć operację? T/N g
# Wpisales coś źle, wracasz do początku
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 4
# O bankietach, bękartach i pochówkach
# Czy chcesz powtórzyć operację? T/N T
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 3
# Zdradziecki księżyc
# Czy chcesz powtórzyć operację? T/N N
# Chcesz zakończyć działanie programu? T/Ng
# Wpisałeś coś źle, wracasz do początku
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 3
# Zdradziecki księżyc
# Czy chcesz powtórzyć operację? T/N N
# Chcesz zakończyć działanie programu? T/NT
# Żegnaj.

# %%
startwiedzmin()
# Out:
# Wybierz wersję językową: (PL/ENG)PL
# Będziesz dostawał polskie tytuły odcinków.
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 4
# O bankietach, bękartach i pochówkach
# Czy chcesz powtórzyć operację? T/N T
# Wpisz numer odcinka od 1 do 8: (Podaj samą cyfre!) 3
# Zdradziecki księżyc
# Czy chcesz powtórzyć operację? T/N N
# Chcesz zakończyć działanie programu? T/NT
# Żegnaj.
